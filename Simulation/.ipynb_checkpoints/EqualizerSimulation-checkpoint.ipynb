# %% [markdown]
# # FPGA Equalizer Simulation
#
# For testing and aiding in the design of the DSP portions of the FPGA Equalizer

# %%
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np
import soundfile as sf

# %% [markdown]
# ## Function definitions

# %%
# converts an array of floats to defined fixed point integers
#def floating_point_to_fixed(array, bit_length, bit_precision) :

# %% [markdown]
# ## Variables and constants

# %%
# user defined parameters
filter_count = 6
Fs = 48000
write_audio_files = True
audio_length_sec = 10
adc_unsigned_bit_length = 12
fixed_point_math_bit_length = 16

# variables
filter_sizes = np.zeros(filter_count, dtype=int)
filter_max_values = np.zeros(filter_count, dtype=float)
filter_min_values = np.zeros(filter_count, dtype=float)
filter_taps = []

# %% [markdown]
# ## Retrieve filter coefficients from files

# %%
# read filter taps from text file
for index in range(filter_count) :
    file_name = "filter{}_taps.txt".format(index+1)
    file = open(file_name, "r")
    text = file.readlines()
    filter_sizes[index] = int(text[0][1:])
    taps = np.array([float(element) for element in text[1:]])
    taps_size_check = len(taps)
    if (taps_size_check != filter_sizes[index]) :
        print("Error: sizes don't match up!")
        print("Defined filter size:", filter_sizes[index])
        print("Actual filter size:", taps_size_check)
    filter_max_values[index] = np.amax(taps)
    filter_min_values[index] = np.amin(taps)
    filter_taps.append(taps)
    file.close()
    
    # print results
    print("Filter{} Size:".format(index+1), filter_sizes[index], "taps")
    print("Filter{} Maximum Tap Value:".format(index+1), filter_max_values[index])
    print("Filter{} Minimum Tap Value:".format(index+1), filter_min_values[index])
    print("")
# Out:
# Filter1 Size: 641 taps
# Filter1 Maximum Tap Value: 0.006013577107663439
# Filter1 Minimum Tap Value: -0.0050859712862627955
#
# Filter2 Size: 623 taps
# Filter2 Maximum Tap Value: 0.011950637977798413
# Filter2 Minimum Tap Value: -0.007238991377913712
#
# Filter3 Size: 623 taps
# Filter3 Maximum Tap Value: 0.03228730918579906
# Filter3 Minimum Tap Value: -0.02082440553225668
#
# Filter4 Size: 591 taps
# Filter4 Maximum Tap Value: 0.09790141310600069
# Filter4 Minimum Tap Value: -0.06216274862567144
#
# Filter5 Size: 1039 taps
# Filter5 Maximum Tap Value: 0.28254632299832394
# Filter5 Minimum Tap Value: -0.18180615571733963
#
# Filter6 Size: 373 taps
# Filter6 Maximum Tap Value: 0.5794082963951053
# Filter6 Minimum Tap Value: -0.30845910505897184

# %% [markdown]
# # Plot floating point filter frequency characteristics

# %%
plt.figure(figsize=(6*filter_count, 3*filter_count))
added_taps = np.zeros(np.amax(filter_sizes))
for index in range(filter_count):
    taps = filter_taps[index]

    # get frequency response
    w, H = signal.freqz(taps)
    angles = np.unwrap(np.angle(H))
    w = w * Fs / (2 * np.pi)
    
    # add filters
    added_taps[0:filter_sizes[index]] = added_taps[0:filter_sizes[index]] + taps

    # plot frequency response
    ax = plt.subplot(3, 2, index+1)
    ax.plot(w, 20 * np.log10(abs(H)))
    ax.set_xlabel('Frequency [Hz]')
    ax.set_ylabel('Amplitude [dB]')
#     ax = plt.subplot(3, 2, index+2)
#     ax.plot(w, angles)
#     ax.set_xlabel('Frequency [Hz]')
#     ax.set_ylabel('Angle (radians)')

# %%
# plot added filters
w, H = signal.freqz(added_taps)
angles = np.unwrap(np.angle(H))
w = w * Fs / (2 * np.pi)
H = 20 * np.log10(abs(H))

plt.plot(w, H)
plt.xlabel('Frequency [Hz]')
plt.ylabel('Amplitude [dB]')
plt.show()

# delete later
# min_index = np.argpartition(H, 4)[:4]
# max_index = np.argpartition(H, -4)[-4:]
# for i, j in min_index, max_index:
#     print("Min. Magnitude:", H[i])
#     print("Min. Frequency:", w[i])
#     print("Max. Magnitude:", H[j])
#     print("Max. Frequency:", w[j])

# %% [markdown]
# ## Convert values to fixed point

# %% [markdown]
# ## Plot fixed point filter frequency characteristics

# %% [markdown]
# ## Simulate filters with input audio

# %%
# simulate floating point filters
if (write_audio_files == True) :
    # get audio
    audio, fs = sf.read('fahey.wav')
    x = audio[fs*5:fs*(5+audio_length_sec)]
    equalized_x = np.zeros(np.shape(x))
    
    # plot frequency contents
    f, t, Sxx = signal.spectrogram(x[0:1000], fs)
    skimage.color.rgb2grey(Sxx)
    plt.pcolormesh(t, f, Sxx, shading='gouraud', cmap='binary')
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    plt.show()
    
    # iterate through filters to simulate equalizer
    for index in range(filter_count):
        taps = filter_taps[index]
        
        # filter individual channels
        filtered_audio = signal.lfilter(taps, 1, x)
        
        # add to equalized audio channel
        equalized_x = equalized_x + filtered_audio[0:np.shape(equalized_x)[0],:]
        
        # write filtered audio to wav file
        file_name = "filtered_audio_float{}.wav".format(index+1)
        sf.write(file_name, filtered_audio, fs)
        
        print("Finished writing out filter{}".format(index+1))
        
        # plot frequency contents
        f, t, Sxx = signal.spectrogram(filtered_audio[0:1000], fs)
        plt.pcolormesh(t, f, Sxx, shading='gouraud')
        plt.ylabel('Frequency [Hz]')
        plt.xlabel('Time [sec]')
        plt.show()
        
    # write out equalized input audio
    sf.write("equalized_audio_float.wav", equalized_x, fs)
    
    print("Finished writing out audio")
# Out:
# C:\Users\jacks\anaconda3\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 2, using nperseg = 2
#   warnings.warn('nperseg = {0:d} is greater than input length '
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a2751f50e524> in <module>
#       8     # plot frequency contents
#       9     f, t, Sxx = signal.spectrogram(x[0:1000], fs)
# ---> 10     plt.pcolormesh(t, f, Sxx, shading='gouraud')
#      11     plt.ylabel('Frequency [Hz]')
#      12     plt.xlabel('Time [sec]')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    2728         vmax=None, shading=None, antialiased=False, data=None,
#    2729         **kwargs):
# -> 2730     __ret = gca().pcolormesh(
#    2731         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2732         vmax=vmax, shading=shading, antialiased=antialiased,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6056         kwargs.setdefault('edgecolors', 'none')
#    6057
# -> 6058         X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6059                                             shading=shading, kwargs=kwargs)
#    6060         coords = np.stack([X, Y], axis=-1)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _pcolorargs(self, funcname, shading, *args, **kwargs)
#    5541                 if isinstance(Y, np.ma.core.MaskedArray):
#    5542                     Y = Y.data
# -> 5543             nrows, ncols = C.shape
#    5544         else:
#    5545             raise TypeError(f'{funcname}() takes 1 or 3 positional arguments '
#
# ValueError: too many values to unpack (expected 2)

# %%
# simulate fixed point filters
# if (write_audio_files == True) :
#     # get audio
#     audio, fs = sf.read('fahey.wav', dtype='int32')
#     x_32bit = audio[fs*5:fs*(5+audio_length_sec)]
    
#     # normalize input audio to 12-bit values (simulates ADC read)
#     signed32bit_max = 2147483647
#     u32bit_to_u12bit = 2**20
#     x_float64 = x_32bit.astype('float64')
#     x_12bit_float64 = (x_float64 + signed32bit_max) / u32bit_to_u12bit
#     x_12bit = x_12bit_float64.astype('int32') - 1

#     # iterate through filters to simulate equalizer
#     for index in range(filter_count):
#         taps = filter_taps[index]
        
#         # filter individual channels
#         filtered_audio_l = np.convolve(taps, x_12bit[:,0], mode='full')
#         filtered_audio_r = np.convolve(taps, x_12bit[:,1], mode='full')
#         #filtered_audio_l = x_12bit[:,0] # delete
#         #filtered_audio_r = x_12bit[:,1] # delete
        
#         # assign filtered audio channels to output array
#         filtered_audio = np.empty((len(filtered_audio_l),2), dtype='int32')
#         filtered_audio[:,0] = filtered_audio_l #/ filter_max_values[index]
#         filtered_audio[:,1] = filtered_audio_r #/ filter_max_values[index]
#         print(filtered_audio_l)
#         print(filtered_audio[:,0])
        
#         # write filtered audio to wav file
#         x_write = filtered_audio * u32bit_to_u12bit - signed32bit_max
#         file_name = "filtered_audio_int{}.wav".format(index+1)
#         sf.write(file_name, x_write, fs)

# %% [markdown]
# ## Write filter coefficients to VHDL

# %%
# write out VHDL readable array
